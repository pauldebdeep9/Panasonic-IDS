# %% [markdown]
# Env: "cre"

# %% [markdown]
# # 01. Stanza
# https://stanfordnlp.github.io/stanza/ner.html

# %%
import stanza

text = "I need a desk on this Tuesday, not next Tuesday, 10 December 2020, from 2pm to 3pm. These are in Q4 of 2020. The time is between 1 to 2 hours."
nlp = stanza.Pipeline('en', processors='tokenize,pos,ner', verbose=False)
doc = nlp(text)
print(*[f'entity: {ent.text}\ttype: {ent.type}' for sent in doc.sentences for ent in sent.ents], sep='\n')
# Out:
# entity: this Tuesday	type: DATE
# entity: next Tuesday, 10 December 2020	type: DATE
# entity: 2pm to 3pm	type: TIME
# entity: Q4 of 2020	type: DATE
# entity: between 1 to 2 hours	type: TIME

# %%
doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "I",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "start_char": 0,
#       "end_char": 1,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "need",
#       "upos": "VERB",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#       "start_char": 2,
#       "end_char": 6,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "start_char": 7,
#       "end_char": 8,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "desk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 9,
#       "end_char": 13,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "on",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 14,
#       "end_char": 16,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "this",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "start_char": 17,
#       "end_char": 21,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "Tuesday",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 22,
#       "end_char": 29,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ]
#     },
#     {
#       "id": 8,
#       "text": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 29,
#       "end_char": 30,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "not",
#       "upos": "PART",
#       "xpos": "RB",
#       "start_char": 31,
#       "end_char": 34,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "next",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "start_char": 35,
#       "end_char": 39,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "Tuesday",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 40,
#       "end_char": 47,
#       "ner": "I-DATE",
#       "multi_ner": [
#         "I-DATE"
#       ]
#     },
#     {
#       "id": 12,
#       "text": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 47,
#       "end_char": 48,
#       "ner": "I-DATE",
#       "multi_ner": [
#         "I-DATE"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "10",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 49,
#       "end_char": 51,
#       "ner": "I-DATE",
#       "multi_ner": [
#         "I-DATE"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "December",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 52,
#       "end_char": 60,
#       "ner": "I-DATE",
#       "multi_ner": [
#         "I-DATE"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "2020",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 61,
#       "end_char": 65,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ]
#     },
#     {
#       "id": 16,
#       "text": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "start_char": 65,
#       "end_char": 66,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 67,
#       "end_char": 71,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 72,
#       "end_char": 73,
#       "ner": "B-TIME",
#       "multi_ner": [
#         "B-TIME"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "pm",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 73,
#       "end_char": 75,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 76,
#       "end_char": 78,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "3",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 79,
#       "end_char": 80,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "pm",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 80,
#       "end_char": 82,
#       "ner": "E-TIME",
#       "multi_ner": [
#         "E-TIME"
#       ]
#     },
#     {
#       "id": 23,
#       "text": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 82,
#       "end_char": 83,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "These",
#       "upos": "PRON",
#       "xpos": "DT",
#       "feats": "Number=Plur|PronType=Dem",
#       "start_char": 84,
#       "end_char": 89,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "are",
#       "upos": "AUX",
#       "xpos": "VBP",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 90,
#       "end_char": 93,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 94,
#       "end_char": 96,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "Q4",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "start_char": 97,
#       "end_char": 99,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 100,
#       "end_char": 102,
#       "ner": "I-DATE",
#       "multi_ner": [
#         "I-DATE"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "2020",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 103,
#       "end_char": 107,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ]
#     },
#     {
#       "id": 7,
#       "text": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 107,
#       "end_char": 108,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "The",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "start_char": 109,
#       "end_char": 112,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "time",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "start_char": 113,
#       "end_char": 117,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "is",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "start_char": 118,
#       "end_char": 120,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "between",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 121,
#       "end_char": 128,
#       "ner": "B-TIME",
#       "multi_ner": [
#         "B-TIME"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 129,
#       "end_char": 130,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "start_char": 131,
#       "end_char": 133,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "start_char": 134,
#       "end_char": 135,
#       "ner": "I-TIME",
#       "multi_ner": [
#         "I-TIME"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "hours",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "start_char": 136,
#       "end_char": 141,
#       "ner": "E-TIME",
#       "multi_ner": [
#         "E-TIME"
#       ]
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "start_char": 141,
#       "end_char": 142,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ]

# %% [markdown]
# # 02. StanfordCoreNLP
# https://github.com/stanfordnlp/stanza/blob/main/demo/Stanza_CoreNLP_Interface.ipynb

# %%
# Import client module
from stanza.server import CoreNLPClient

# %%
# Set the CORENLP_HOME environment variable to point to the installation location
import os
os.environ["CORENLP_HOME"] = r"C:\Users\effbl\stanza_corenlp\stanford-corenlp-4.2.2"

# %%
# Construct a CoreNLPClient with some basic annotators, a memory allocation of 4GB, and port number 9001
client = CoreNLPClient(
    annotators=['tokenize','ssplit','ner'], 
    memory='4G', 
    endpoint='http://localhost:9000',
    be_quiet=True)
print(client)

# Start the background server and wait for some time
# Note that in practice this is totally optional, as by default the server will be started when the first annotation is performed
client.start()
import time; time.sleep(10)
# Out:
# <stanza.server.client.CoreNLPClient object at 0x0000022833E9C388>

# %%
# Print background processes and look for java
# You should be able to see a StanfordCoreNLPServer java process running in the background
# !ps -o pid,cmd | grep java
# Out:
# 'ps' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Annotate some text
text = "I need a desk on this Tuesday, not next Tuesday, 10 December 2020, from 2pm to 3pm. These are in Q4 of 2020. The time is between 1 to 2 hours."
document = client.annotate(text)
print(type(document))
# Out:
# <class 'CoreNLP_pb2.Document'>

# %%
document.sentence
# Out:
# [token {
#   word: "I"
#   pos: "PRP"
#   value: "I"
#   before: ""
#   after: " "
#   originalText: "I"
#   ner: "O"
#   lemma: "I"
#   beginChar: 0
#   endChar: 1
#   tokenBeginIndex: 0
#   tokenEndIndex: 1
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999627153845908"
# }
# token {
#   word: "need"
#   pos: "VBP"
#   value: "need"
#   before: " "
#   after: " "
#   originalText: "need"
#   ner: "O"
#   lemma: "need"
#   beginChar: 2
#   endChar: 6
#   tokenBeginIndex: 1
#   tokenEndIndex: 2
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999983188358704"
# }
# token {
#   word: "a"
#   pos: "DT"
#   value: "a"
#   before: " "
#   after: " "
#   originalText: "a"
#   ner: "O"
#   lemma: "a"
#   beginChar: 7
#   endChar: 8
#   tokenBeginIndex: 2
#   tokenEndIndex: 3
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999979942182556"
# }
# token {
#   word: "desk"
#   pos: "NN"
#   value: "desk"
#   before: " "
#   after: " "
#   originalText: "desk"
#   ner: "O"
#   lemma: "desk"
#   beginChar: 9
#   endChar: 13
#   tokenBeginIndex: 3
#   tokenEndIndex: 4
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999961282041375"
# }
# token {
#   word: "on"
#   pos: "IN"
#   value: "on"
#   before: " "
#   after: " "
#   originalText: "on"
#   ner: "O"
#   lemma: "on"
#   beginChar: 14
#   endChar: 16
#   tokenBeginIndex: 4
#   tokenEndIndex: 5
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999993482090722"
# }
# token {
#   word: "this"
#   pos: "DT"
#   value: "this"
#   before: " "
#   after: " "
#   originalText: "this"
#   ner: "DATE"
#   normalizedNER: "THIS XXXX-WXX-2"
#   lemma: "this"
#   beginChar: 17
#   endChar: 21
#   tokenBeginIndex: 5
#   tokenEndIndex: 6
#   timexValue {
#     altValue: "THIS XXXX-WXX-2"
#     text: "this Tuesday"
#     type: "DATE"
#     tid: "t1"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 0
#   nerLabelProbs: "DATE=-1.0"
# }
# token {
#   word: "Tuesday"
#   pos: "NNP"
#   value: "Tuesday"
#   before: " "
#   after: ""
#   originalText: "Tuesday"
#   ner: "DATE"
#   normalizedNER: "THIS XXXX-WXX-2"
#   lemma: "Tuesday"
#   beginChar: 22
#   endChar: 29
#   tokenBeginIndex: 6
#   tokenEndIndex: 7
#   timexValue {
#     altValue: "THIS XXXX-WXX-2"
#     text: "this Tuesday"
#     type: "DATE"
#     tid: "t1"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 0
#   nerLabelProbs: "DATE=0.9996958058743447"
# }
# token {
#   word: ","
#   pos: ","
#   value: ","
#   before: ""
#   after: " "
#   originalText: ","
#   ner: "O"
#   lemma: ","
#   beginChar: 29
#   endChar: 30
#   tokenBeginIndex: 7
#   tokenEndIndex: 8
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999996393687607"
# }
# token {
#   word: "not"
#   pos: "RB"
#   value: "not"
#   before: " "
#   after: " "
#   originalText: "not"
#   ner: "O"
#   lemma: "not"
#   beginChar: 31
#   endChar: 34
#   tokenBeginIndex: 8
#   tokenEndIndex: 9
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999766626194014"
# }
# token {
#   word: "next"
#   pos: "JJ"
#   value: "next"
#   before: " "
#   after: " "
#   originalText: "next"
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: "next"
#   beginChar: 35
#   endChar: 39
#   tokenBeginIndex: 9
#   tokenEndIndex: 10
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=-1.0"
# }
# token {
#   word: "Tuesday"
#   pos: "NNP"
#   value: "Tuesday"
#   before: " "
#   after: ""
#   originalText: "Tuesday"
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: "Tuesday"
#   beginChar: 40
#   endChar: 47
#   tokenBeginIndex: 10
#   tokenEndIndex: 11
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=0.9995689223711446"
# }
# token {
#   word: ","
#   pos: ","
#   value: ","
#   before: ""
#   after: " "
#   originalText: ","
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: ","
#   beginChar: 47
#   endChar: 48
#   tokenBeginIndex: 11
#   tokenEndIndex: 12
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=-1.0"
# }
# token {
#   word: "10"
#   pos: "CD"
#   value: "10"
#   before: " "
#   after: " "
#   originalText: "10"
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: "10"
#   beginChar: 49
#   endChar: 51
#   tokenBeginIndex: 12
#   tokenEndIndex: 13
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=-1.0"
#   numericValue: 10
#   numericType: "NUMBER"
#   numericCompositeValue: 10
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "December"
#   pos: "NNP"
#   value: "December"
#   before: " "
#   after: " "
#   originalText: "December"
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: "December"
#   beginChar: 52
#   endChar: 60
#   tokenBeginIndex: 13
#   tokenEndIndex: 14
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=0.9680029163602821"
# }
# token {
#   word: "2020"
#   pos: "CD"
#   value: "2020"
#   before: " "
#   after: ""
#   originalText: "2020"
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   lemma: "2020"
#   beginChar: 61
#   endChar: 65
#   tokenBeginIndex: 14
#   tokenEndIndex: 15
#   timexValue {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 1
#   nerLabelProbs: "DATE=0.9680029163602821"
#   numericValue: 2020
#   numericType: "NUMBER"
#   numericCompositeValue: 2020
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: ","
#   pos: ","
#   value: ","
#   before: ""
#   after: " "
#   originalText: ","
#   ner: "O"
#   lemma: ","
#   beginChar: 65
#   endChar: 66
#   tokenBeginIndex: 15
#   tokenEndIndex: 16
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999995702582183"
# }
# token {
#   word: "from"
#   pos: "IN"
#   value: "from"
#   before: " "
#   after: " "
#   originalText: "from"
#   ner: "O"
#   lemma: "from"
#   beginChar: 67
#   endChar: 71
#   tokenBeginIndex: 16
#   tokenEndIndex: 17
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999964812669707"
# }
# token {
#   word: "2"
#   pos: "CD"
#   value: "2"
#   before: " "
#   after: ""
#   originalText: "2"
#   ner: "TIME"
#   normalizedNER: "T14:00"
#   lemma: "2"
#   beginChar: 72
#   endChar: 73
#   tokenBeginIndex: 17
#   tokenEndIndex: 18
#   timexValue {
#     value: "T14:00"
#     text: "2pm"
#     type: "TIME"
#     tid: "t4"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "TIME"
#   fineGrainedNER: "TIME"
#   entityMentionIndex: 2
#   nerLabelProbs: "TIME=-1.0"
#   numericValue: 2
#   numericType: "NUMBER"
#   numericCompositeValue: 2
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "pm"
#   pos: "NN"
#   value: "pm"
#   before: ""
#   after: " "
#   originalText: "pm"
#   ner: "TIME"
#   normalizedNER: "T14:00"
#   lemma: "pm"
#   beginChar: 73
#   endChar: 75
#   tokenBeginIndex: 18
#   tokenEndIndex: 19
#   timexValue {
#     value: "T14:00"
#     text: "2pm"
#     type: "TIME"
#     tid: "t4"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "TIME"
#   fineGrainedNER: "TIME"
#   entityMentionIndex: 2
#   nerLabelProbs: "TIME=-1.0"
# }
# token {
#   word: "to"
#   pos: "IN"
#   value: "to"
#   before: " "
#   after: " "
#   originalText: "to"
#   ner: "O"
#   lemma: "to"
#   beginChar: 76
#   endChar: 78
#   tokenBeginIndex: 19
#   tokenEndIndex: 20
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999990072505892"
# }
# token {
#   word: "3"
#   pos: "CD"
#   value: "3"
#   before: " "
#   after: ""
#   originalText: "3"
#   ner: "TIME"
#   normalizedNER: "T15:00"
#   lemma: "3"
#   beginChar: 79
#   endChar: 80
#   tokenBeginIndex: 20
#   tokenEndIndex: 21
#   timexValue {
#     value: "T15:00"
#     text: "3pm."
#     type: "TIME"
#     tid: "t5"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "TIME"
#   fineGrainedNER: "TIME"
#   entityMentionIndex: 3
#   nerLabelProbs: "TIME=-1.0"
#   numericValue: 3
#   numericType: "NUMBER"
#   numericCompositeValue: 3
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "pm"
#   pos: "NN"
#   value: "pm"
#   before: ""
#   after: ""
#   originalText: "pm"
#   ner: "TIME"
#   normalizedNER: "T15:00"
#   lemma: "pm"
#   beginChar: 80
#   endChar: 82
#   tokenBeginIndex: 21
#   tokenEndIndex: 22
#   timexValue {
#     value: "T15:00"
#     text: "3pm."
#     type: "TIME"
#     tid: "t5"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "TIME"
#   fineGrainedNER: "TIME"
#   entityMentionIndex: 3
#   nerLabelProbs: "TIME=-1.0"
# }
# token {
#   word: "."
#   pos: "."
#   value: "."
#   before: ""
#   after: " "
#   originalText: "."
#   ner: "TIME"
#   normalizedNER: "T15:00"
#   lemma: "."
#   beginChar: 82
#   endChar: 83
#   tokenBeginIndex: 22
#   tokenEndIndex: 23
#   timexValue {
#     value: "T15:00"
#     text: "3pm."
#     type: "TIME"
#     tid: "t5"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "TIME"
#   fineGrainedNER: "TIME"
#   entityMentionIndex: 3
#   nerLabelProbs: "TIME=-1.0"
# }
# tokenOffsetBegin: 0
# tokenOffsetEnd: 23
# sentenceIndex: 0
# characterOffsetBegin: 0
# characterOffsetEnd: 83
# hasRelationAnnotations: false
# hasNumerizedTokensAnnotation: false
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 5
#   tokenEndInSentenceExclusive: 7
#   ner: "DATE"
#   normalizedNER: "THIS XXXX-WXX-2"
#   entityType: "DATE"
#   timex {
#     altValue: "THIS XXXX-WXX-2"
#     text: "this Tuesday"
#     type: "DATE"
#     tid: "t1"
#   }
#   entityMentionIndex: 0
#   canonicalEntityMentionIndex: 0
#   entityMentionText: "this Tuesday"
# }
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 9
#   tokenEndInSentenceExclusive: 15
#   ner: "DATE"
#   normalizedNER: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#   entityType: "DATE"
#   timex {
#     altValue: "XXXX-WXX-2 OFFSET P1W INTERSECT 2020-12-10"
#     text: "next Tuesday, 10 December 2020"
#     type: "DATE"
#     tid: "t2"
#   }
#   entityMentionIndex: 1
#   canonicalEntityMentionIndex: 1
#   entityMentionText: "next Tuesday, 10 December 2020"
# }
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 17
#   tokenEndInSentenceExclusive: 19
#   ner: "TIME"
#   normalizedNER: "T14:00"
#   entityType: "TIME"
#   timex {
#     value: "T14:00"
#     text: "2pm"
#     type: "TIME"
#     tid: "t4"
#   }
#   entityMentionIndex: 2
#   canonicalEntityMentionIndex: 2
#   entityMentionText: "2pm"
# }
# mentions {
#   sentenceIndex: 0
#   tokenStartInSentenceInclusive: 20
#   tokenEndInSentenceExclusive: 23
#   ner: "TIME"
#   normalizedNER: "T15:00"
#   entityType: "TIME"
#   timex {
#     value: "T15:00"
#     text: "3pm."
#     type: "TIME"
#     tid: "t5"
#   }
#   entityMentionIndex: 3
#   canonicalEntityMentionIndex: 3
#   entityMentionText: "3pm."
# }
# hasEntityMentionsAnnotation: true
# , token {
#   word: "These"
#   pos: "DT"
#   value: "These"
#   before: " "
#   after: " "
#   originalText: "These"
#   ner: "O"
#   lemma: "these"
#   beginChar: 84
#   endChar: 89
#   tokenBeginIndex: 23
#   tokenEndIndex: 24
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9998635293061848"
# }
# token {
#   word: "are"
#   pos: "VBP"
#   value: "are"
#   before: " "
#   after: " "
#   originalText: "are"
#   ner: "O"
#   lemma: "be"
#   beginChar: 90
#   endChar: 93
#   tokenBeginIndex: 24
#   tokenEndIndex: 25
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999988570150715"
# }
# token {
#   word: "in"
#   pos: "IN"
#   value: "in"
#   before: " "
#   after: " "
#   originalText: "in"
#   ner: "O"
#   lemma: "in"
#   beginChar: 94
#   endChar: 96
#   tokenBeginIndex: 25
#   tokenEndIndex: 26
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999861762442445"
# }
# token {
#   word: "Q4"
#   pos: "NN"
#   value: "Q4"
#   before: " "
#   after: " "
#   originalText: "Q4"
#   ner: "DATE"
#   normalizedNER: "2020-FYQ4"
#   lemma: "q4"
#   beginChar: 97
#   endChar: 99
#   tokenBeginIndex: 26
#   tokenEndIndex: 27
#   timexValue {
#     value: "2020-FYQ4"
#     text: "Q4 of 2020"
#     type: "DATE"
#     tid: "t6"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 4
#   nerLabelProbs: "DATE=-1.0"
# }
# token {
#   word: "of"
#   pos: "IN"
#   value: "of"
#   before: " "
#   after: " "
#   originalText: "of"
#   ner: "DATE"
#   normalizedNER: "2020-FYQ4"
#   lemma: "of"
#   beginChar: 100
#   endChar: 102
#   tokenBeginIndex: 27
#   tokenEndIndex: 28
#   timexValue {
#     value: "2020-FYQ4"
#     text: "Q4 of 2020"
#     type: "DATE"
#     tid: "t6"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 4
#   nerLabelProbs: "DATE=-1.0"
# }
# token {
#   word: "2020"
#   pos: "CD"
#   value: "2020"
#   before: " "
#   after: ""
#   originalText: "2020"
#   ner: "DATE"
#   normalizedNER: "2020-FYQ4"
#   lemma: "2020"
#   beginChar: 103
#   endChar: 107
#   tokenBeginIndex: 28
#   tokenEndIndex: 29
#   timexValue {
#     value: "2020-FYQ4"
#     text: "Q4 of 2020"
#     type: "DATE"
#     tid: "t6"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DATE"
#   fineGrainedNER: "DATE"
#   entityMentionIndex: 4
#   nerLabelProbs: "DATE=0.894748156821182"
#   numericValue: 2020
#   numericType: "NUMBER"
#   numericCompositeValue: 2020
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "."
#   pos: "."
#   value: "."
#   before: ""
#   after: " "
#   originalText: "."
#   ner: "O"
#   lemma: "."
#   beginChar: 107
#   endChar: 108
#   tokenBeginIndex: 29
#   tokenEndIndex: 30
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999997402273291"
# }
# tokenOffsetBegin: 23
# tokenOffsetEnd: 30
# sentenceIndex: 1
# characterOffsetBegin: 84
# characterOffsetEnd: 108
# hasRelationAnnotations: false
# hasNumerizedTokensAnnotation: false
# mentions {
#   sentenceIndex: 1
#   tokenStartInSentenceInclusive: 26
#   tokenEndInSentenceExclusive: 29
#   ner: "DATE"
#   normalizedNER: "2020-FYQ4"
#   entityType: "DATE"
#   timex {
#     value: "2020-FYQ4"
#     text: "Q4 of 2020"
#     type: "DATE"
#     tid: "t6"
#   }
#   entityMentionIndex: 4
#   canonicalEntityMentionIndex: 4
#   entityMentionText: "Q4 of 2020"
# }
# hasEntityMentionsAnnotation: true
# , token {
#   word: "The"
#   pos: "DT"
#   value: "The"
#   before: " "
#   after: " "
#   originalText: "The"
#   ner: "O"
#   lemma: "the"
#   beginChar: 109
#   endChar: 112
#   tokenBeginIndex: 30
#   tokenEndIndex: 31
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999953725185752"
# }
# token {
#   word: "time"
#   pos: "NN"
#   value: "time"
#   before: " "
#   after: " "
#   originalText: "time"
#   ner: "O"
#   lemma: "time"
#   beginChar: 113
#   endChar: 117
#   tokenBeginIndex: 31
#   tokenEndIndex: 32
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999744290341901"
# }
# token {
#   word: "is"
#   pos: "VBZ"
#   value: "is"
#   before: " "
#   after: " "
#   originalText: "is"
#   ner: "O"
#   lemma: "be"
#   beginChar: 118
#   endChar: 120
#   tokenBeginIndex: 32
#   tokenEndIndex: 33
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999998009852276"
# }
# token {
#   word: "between"
#   pos: "IN"
#   value: "between"
#   before: " "
#   after: " "
#   originalText: "between"
#   ner: "O"
#   lemma: "between"
#   beginChar: 121
#   endChar: 128
#   tokenBeginIndex: 33
#   tokenEndIndex: 34
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999876740551709"
# }
# token {
#   word: "1"
#   pos: "CD"
#   value: "1"
#   before: " "
#   after: " "
#   originalText: "1"
#   ner: "DURATION"
#   normalizedNER: "PT1H/PT2H"
#   lemma: "1"
#   beginChar: 129
#   endChar: 130
#   tokenBeginIndex: 34
#   tokenEndIndex: 35
#   timexValue {
#     altValue: "PT1H/PT2H"
#     text: "1 to 2 hours"
#     type: "DURATION"
#     tid: "t7"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DURATION"
#   fineGrainedNER: "DURATION"
#   entityMentionIndex: 5
#   nerLabelProbs: "DURATION=-1.0"
#   numericValue: 1
#   numericType: "NUMBER"
#   numericCompositeValue: 1
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "to"
#   pos: "IN"
#   value: "to"
#   before: " "
#   after: " "
#   originalText: "to"
#   ner: "DURATION"
#   normalizedNER: "PT1H/PT2H"
#   lemma: "to"
#   beginChar: 131
#   endChar: 133
#   tokenBeginIndex: 35
#   tokenEndIndex: 36
#   timexValue {
#     altValue: "PT1H/PT2H"
#     text: "1 to 2 hours"
#     type: "DURATION"
#     tid: "t7"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DURATION"
#   fineGrainedNER: "DURATION"
#   entityMentionIndex: 5
#   nerLabelProbs: "DURATION=-1.0"
# }
# token {
#   word: "2"
#   pos: "CD"
#   value: "2"
#   before: " "
#   after: " "
#   originalText: "2"
#   ner: "DURATION"
#   normalizedNER: "PT1H/PT2H"
#   lemma: "2"
#   beginChar: 134
#   endChar: 135
#   tokenBeginIndex: 36
#   tokenEndIndex: 37
#   timexValue {
#     altValue: "PT1H/PT2H"
#     text: "1 to 2 hours"
#     type: "DURATION"
#     tid: "t7"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DURATION"
#   fineGrainedNER: "DURATION"
#   entityMentionIndex: 5
#   nerLabelProbs: "DURATION=-1.0"
#   numericValue: 2
#   numericType: "NUMBER"
#   numericCompositeValue: 2
#   numericCompositeType: "NUMBER"
# }
# token {
#   word: "hours"
#   pos: "NNS"
#   value: "hours"
#   before: " "
#   after: ""
#   originalText: "hours"
#   ner: "DURATION"
#   normalizedNER: "PT1H/PT2H"
#   lemma: "hour"
#   beginChar: 136
#   endChar: 141
#   tokenBeginIndex: 37
#   tokenEndIndex: 38
#   timexValue {
#     altValue: "PT1H/PT2H"
#     text: "1 to 2 hours"
#     type: "DURATION"
#     tid: "t7"
#   }
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "DURATION"
#   fineGrainedNER: "DURATION"
#   entityMentionIndex: 5
#   nerLabelProbs: "DURATION=-1.0"
# }
# token {
#   word: "."
#   pos: "."
#   value: "."
#   before: ""
#   after: ""
#   originalText: "."
#   ner: "O"
#   lemma: "."
#   beginChar: 141
#   endChar: 142
#   tokenBeginIndex: 38
#   tokenEndIndex: 39
#   hasXmlContext: false
#   isNewline: false
#   coarseNER: "O"
#   fineGrainedNER: "O"
#   nerLabelProbs: "O=0.9999997870982553"
# }
# tokenOffsetBegin: 30
# tokenOffsetEnd: 39
# sentenceIndex: 2
# characterOffsetBegin: 109
# characterOffsetEnd: 142
# hasRelationAnnotations: false
# hasNumerizedTokensAnnotation: false
# mentions {
#   sentenceIndex: 2
#   tokenStartInSentenceInclusive: 34
#   tokenEndInSentenceExclusive: 38
#   ner: "DURATION"
#   normalizedNER: "PT1H/PT2H"
#   entityType: "DURATION"
#   timex {
#     altValue: "PT1H/PT2H"
#     text: "1 to 2 hours"
#     type: "DURATION"
#     tid: "t7"
#   }
#   entityMentionIndex: 5
#   canonicalEntityMentionIndex: 5
#   entityMentionText: "1 to 2 hours"
# }
# hasEntityMentionsAnnotation: true
# ]

# %%
# Get tokens that have TIMEX infos

timex_infos = []
for i, sent in enumerate(document.sentence):
    for j,t in enumerate(sent.token):
        if t.timexValue.text!='':
            timex_infos.append({
                'sent_id': i,
                'word_id': j,
                'word': t.word,
                'value': t.timexValue.value,
                'altValue': t.timexValue.altValue,
                'text': t.timexValue.text,
                'type': t.timexValue.type,
            })

            
# Consolidate tokens that refer to the same TIMEX

current = None
consolidate_timex_infos = []

for i,d in enumerate(timex_infos):
    if current is None: # new item
        current = d
    else:
        # check if new or append to old
        if i==len(timex_infos)-1: # last
            consolidate_timex_infos.append({
                'sent_id': current['sent_id'],
                'word_id': str(current['word_id'])+'_'+str(d['word_id']),
                'word': current['word'],
                'value': current['value'],
                'altValue': current['altValue'],
                'text': current['text'],
                'type': current['type'],
            })
        elif (d['value']==current['value']) and (d['type']==current['type']):
            pass
        else:
            consolidate_timex_infos.append({
                'sent_id': current['sent_id'],
                'word_id': str(current['word_id'])+'_'+str(timex_infos[i-1]['word_id']),
                'word': current['word'],
                'value': current['value'],
                'altValue': current['altValue'],
                'text': current['text'],
                'type': current['type'],
            })
            current = None
            
consolidate_timex_infos
# Out:
# [{'sent_id': 0,
#   'word_id': '5_14',
#   'word': 'this',
#   'value': '',
#   'altValue': 'THIS XXXX-WXX-2',
#   'text': 'this Tuesday',
#   'type': 'DATE'},
#  {'sent_id': 0,
#   'word_id': '18_18',
#   'word': 'pm',
#   'value': 'T14:00',
#   'altValue': '',
#   'text': '2pm',
#   'type': 'TIME'},
#  {'sent_id': 0,
#   'word_id': '21_22',
#   'word': 'pm',
#   'value': 'T15:00',
#   'altValue': '',
#   'text': '3pm.',
#   'type': 'TIME'},
#  {'sent_id': 1,
#   'word_id': '4_5',
#   'word': 'of',
#   'value': '2020-FYQ4',
#   'altValue': '',
#   'text': 'Q4 of 2020',
#   'type': 'DATE'},
#  {'sent_id': 2,
#   'word_id': '5_7',
#   'word': 'to',
#   'value': '',
#   'altValue': 'PT1H/PT2H',
#   'text': '1 to 2 hours',
#   'type': 'DURATION'}]
