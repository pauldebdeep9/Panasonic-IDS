# %%
# https://lvngd.com/blog/named-entity-recognition-in-python-with-stanford-ner-and-spacy/
# download models to : C:\Users\effbl\stanza_corenlp\stanford-ner-2020-11-17
# model from: https://nlp.stanford.edu/software/CRF-NER.shtml#Download

import nltk
from nltk.tag.stanford import StanfordNERTagger
import os

java_path = r"C:\Program Files\AdoptOpenJDK\jdk-11.0.7.10-hotspot\bin\java.exe"
PATH_TO_JAR= r"C:\Users\effbl\stanza_corenlp\stanford-ner-2020-11-17\stanford-ner.jar"
PATH_TO_MODEL = r"C:\Users\effbl\stanza_corenlp\stanford-ner-2020-11-17\classifiers\english.muc.7class.distsim.crf.ser.gz"

os.environ['JAVAHOME'] = java_path
tagger = StanfordNERTagger(model_filename=PATH_TO_MODEL,path_to_jar=PATH_TO_JAR, encoding='utf-8')

# %%
import os
import re
import pandas as pd
from tqdm import tqdm
from copy import copy

graph_folder = r"D:\66 CausalMap\SciLit_CausalMap\visualization\mir"
csv_file_path = os.path.join(graph_folder,'graph_spans.csv')
data = pd.read_csv(csv_file_path)
data
# Out:
#                                                  effect  source  support  \
# 0     " A U . S . facility would need a better U . S...   f-476        1
# 1     " As a result of great uncertainties , Finns s...  f-4849        2
# 2               " Being profitable in India is possible    f-29        1
# 3     " But real challenge is bringing in maximum sa...   f-123        1
# 4     " China ' s high - speed lines are ruthlessly ...  f-5198        1
# ...                                                 ...     ...      ...
# 6432                                    ” SOURCE : ACEA  f-1804        1
# 6433  ” Stopping work at the factory would harm Stel...   f-808        1
# 6434  ” The slowdown in China is likely to have knoc...  f-4742        1
# 6435  ” don ’ t expect to see it on Australian stree...  f-4473        1
# 6436                                             … no .  f-4236        1
#
#                                                evidence  \
# 0     "A U.S. facility would need a better U.S. supp...
# 1     "As a result of great uncertainties, Finns sho...
# 2     "Being profitable in India is possible if you ...
# 3     "But real challenge is bringing in maximum saf...
# 4     "China's high-speed lines are ruthlessly effic...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433  We have people in Russia and we love them also...
# 6434  “This will lock China substantially out of the...
# 6435  While the revealed car is “production ready” d...
# 6436  Well, it seems highly unlikely that GM Special...
#
#                                                   cause
# 0     to get similar to the low cost available in Ch...
# 1        a possible power shortage in the coming winter
# 2                           you do things the India way
# 3             cost of vehicles does not go up steeply .
# 4     once booked , a swipe of your ID card or passp...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433   We have people in Russia and we love them also .
# 6434  “ This will lock China substantially out of th...
# 6435  VW prioritises markets with stricter emissions...
# 6436  Well , it seems highly unlikely that GM Specia...
#
# [6437 rows x 5 columns]

# %%
# classes = ['LOCATION','PERSON','ORGANIZATION','MONEY','PERCENT','DATE','TIME']
DEMO_SIZE = None
REDUCE_SIZE = None #REDUCE_SIZE = int(N_TOPICS/2)
TOP_N_WORDS = 15

# %%
if DEMO_SIZE is None:
    N_TOPICS = int(len(data)*2*0.3)
else:
    N_TOPICS = int(DEMO_SIZE*0.3)

if DEMO_SIZE is not None:
    data = data[:int(DEMO_SIZE/2)]

# %%
template = {
    'ORGANIZATION': [],
    'LOCATION': [],
    'DATE': [],
    'TIME': [],
    'ACTION': [],
    'OBJECT': []
}

# %%
batch_size = 200
n_batches = (len(data)//batch_size)+1
print(n_batches)
# Out:
# 33

# %%
def get_node_infos(data):
    
    cause_action = []
    effect_action = []
    cause_action_rem = []
    effect_action_rem = []
    evidence_ner = []
    cause_store = []
    effect_store = []

    whitespace = '\s*'
    specials = ['*','+','(',')'] # need to escape special regex chars
    
    for i,row in tqdm(data.iterrows(), total=data.shape[0]):
        cause = row.cause
        effect = row.effect
        cause_rem = cause
        effect_rem = effect
        sentence = row.evidence    
        words = nltk.word_tokenize(sentence) 
        tagged = tagger.tag(words)
        tagged2 = []
        curr_word = ''
        curr_ner = None
        for (word,ner) in tagged:
            if ner==curr_ner: # same, continue
                curr_word+=str(word)
            else: # different
                if curr_ner is not None:
                    tagged2.append((curr_word,curr_ner))
                # reset
                if ner=='O':
                    curr_ner=None
                    curr_word=''
                else:
                    curr_ner=ner
                    curr_word=word

        cause_template = copy(template)
        effect_template = copy(template)
        for (word,ner) in tagged2:
            if ner!='O':
#                 pattern = ''.join([str(c)+whitespace for c in word])
#                 pattern = re.sub('\(','\(',re.sub('\)','\)', pattern)) # escape special parenthesis
                pattern = ''.join(["\\"+str(c)+whitespace if c in specials else str(c)+whitespace for c in word])
                pattern = pattern[:-3]

                match = re.findall(pattern, cause)
                if match is not None:
                    cause_template[ner] =  list(match)
                    cause = re.sub(pattern, f'[{ner}]', cause)
                    cause_rem = re.sub(pattern, '[MASK]', cause_rem)

                match = re.findall(pattern, effect)
                if match is not None:
                    effect_template[ner] =  list(match)
                    effect = re.sub(pattern, f'[{ner}]', effect)
                    effect_rem = re.sub(pattern, '[MASK]', effect_rem)

        pos_tag = nltk.pos_tag(nltk.word_tokenize(re.sub('\[MASK\]','',cause_rem)))
        cause_template['ACTION'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['VB']])
        cause_template['OBJECT'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['NN']])

        pos_tag = nltk.pos_tag(nltk.word_tokenize(re.sub('\[MASK\]','',effect_rem)))
        effect_template['ACTION'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['VB']])
        effect_template['OBJECT'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['NN']])

        cause_action.append(cause)
        effect_action.append(effect)
        cause_action_rem.append(cause_rem)
        effect_action_rem.append(effect_rem)
        evidence_ner.append(tagged)
        cause_store.append(cause_template)
        effect_store.append(effect_template)

    data['cause_action'] = cause_action
    data['effect_action'] = effect_action
    data['cause_action_rem'] = cause_action_rem
    data['effect_action_rem'] = effect_action_rem
    data['evidence_ner'] = evidence_ner
    data['cause_store'] = cause_store
    data['effect_store'] = effect_store
    
    return data


continue_from = 21
if continue_from is None:
    final = pd.DataFrame()
    loop = range(n_batches)
else:
    loop = range(continue_from,n_batches)
    
for batch_id in loop:
    print(f'batch: {batch_id}')
    subset = get_node_infos(data[batch_id*batch_size:(batch_id+1)*batch_size])
    final = pd.concat([final,subset],axis=0)
    final.to_pickle(f"nodes_extracted_infos.pkl") # backup
# Out:
# batch: 21
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [07:12<00:00,  2.16s/it]
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# batch: 22
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:17<00:00,  2.49s/it]
# batch: 23
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:23<00:00,  2.52s/it]
# batch: 24
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:04<00:00,  2.42s/it]
# batch: 25
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:21<00:00,  2.51s/it]
# batch: 26
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:01<00:00,  2.41s/it]
# batch: 27
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [07:45<00:00,  2.33s/it]
# batch: 28
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [07:20<00:00,  2.20s/it]
# batch: 29
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:02<00:00,  2.41s/it]
# batch: 30
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [07:43<00:00,  2.32s/it]
# batch: 31
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [07:54<00:00,  2.37s/it]
# batch: 32
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [01:22<00:00,  2.24s/it]

# %%
# ##### For Debugging

# row = data.iloc[batch_id*batch_size+75]

# whitespace = '\s*'
# specials = ['*','+','(',')'] # need to escape special regex chars

# cause = row.cause
# effect = row.effect
# cause_rem = cause
# effect_rem = effect
# sentence = row.evidence

# words = nltk.word_tokenize(sentence) 
# tagged = tagger.tag(words)
# tagged2 = []
# curr_word = ''
# curr_ner = None
# for (word,ner) in tagged:
#     if ner==curr_ner: # same, continue
#         curr_word+=str(word)
#     else: # different
#         if curr_ner is not None:
#             tagged2.append((curr_word,curr_ner))
#         # reset
#         if ner=='O':
#             curr_ner=None
#             curr_word=''
#         else:
#             curr_ner=ner
#             curr_word=word
# print(tagged2)

# cause_template = copy(template)
# effect_template = copy(template)
# for (word,ner) in tagged2:
#     if ner!='O':
#         pattern = ''.join(["\\"+str(c)+whitespace if c in specials else str(c)+whitespace for c in word])
#         pattern = pattern[:-3]

#         match = re.findall(pattern, cause)
#         if match is not None:
#             cause_template[ner] =  list(match)
#             cause = re.sub(pattern, f'[{ner}]', cause)
#             cause_rem = re.sub(pattern, '[MASK]', cause_rem)

#         match = re.findall(pattern, effect)
#         if match is not None:
#             effect_template[ner] =  list(match)
#             effect = re.sub(pattern, f'[{ner}]', effect)
#             effect_rem = re.sub(pattern, '[MASK]', effect_rem)

# pos_tag = nltk.pos_tag(nltk.word_tokenize(re.sub('\[MASK\]','',cause_rem)))
# cause_template['ACTION'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['VB']])
# cause_template['OBJECT'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['NN']])

# pos_tag = nltk.pos_tag(nltk.word_tokenize(re.sub('\[MASK\]','',effect_rem)))
# effect_template['ACTION'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['VB']])
# effect_template['OBJECT'] = ' '.join([str(word) for word,tag in pos_tag if tag[:2] in ['NN']])

# %%
data = final
del(final)
# data = pd.read_pickle("nodes_extracted_infos.pkl")

# %%
# from collections import Counter

# objects = {}
# for i,d in enumerate(cause_store):
#     obj = d['OBJECT'].lower().split(' ')
#     for o in obj:
#         if o not in objects.keys():
#             objects[o] = [f'c{i}']
#         else:
#             objects[o].append(f'c{i}')
# for i,d in enumerate(effect_store):
#     obj = d['OBJECT'].lower().split(' ')
#     for o in obj:
#         if o not in objects.keys():
#             objects[o] = [f'e{i}']
#         else:
#             objects[o].append(f'e{i}')

# top_objects = []
# cut_off = 2
# indexes_to_keep = []
# for k,v in objects.items():
#     if len(v)>=cut_off and len(k)>1:
#         top_objects.append(k)
#         indexes_to_keep.extend(v)
# cause_indexes_to_keep = [int(i[1:]) for i in indexes_to_keep if i[0]=='c']
# effect_indexes_to_keep = [int(i[1:]) for i in indexes_to_keep if i[0]=='e']
# indexes_to_keep = list(set(cause_indexes_to_keep) & set(effect_indexes_to_keep))
# top_objects

# %%
# tmp = data.loc[indexes_to_keep].reset_index(drop=True)
# tmp

# %%
# graph_folder = r"D:\66 CausalMap\SciLit_CausalMap\visualization\mir_clust"
# headers = ['cause','effect','source','support','evidence']

# rows = []
# for i,row in tmp.iterrows():
#     if row['cause'][:2].lower()=='to':
#         # flip cause and effect
#         rows.append([
#             str(row.effect_store['ACTION']+' '+row.effect_store['OBJECT']),
#             str(row.cause_store['ACTION']+' '+row.cause_store['OBJECT']),
#             str(row.source),
#             int(row['support']),
#             row['cause']+' --> '+row['effect'] + '/// ' + str(row['cause_store'])+' --> '+str(row['effect_store'])
#         ])
#     else:
#         rows.append([
#             str(row.cause_store['ACTION']+' '+row.cause_store['OBJECT']),
#             str(row.effect_store['ACTION']+' '+row.effect_store['OBJECT']),
#             str(row.source),
#             int(row['support']),
#             row['cause']+' --> '+row['effect'] + '/// ' + str(row['cause_store'])+' --> '+str(row['effect_store'])
#         ])
# graph_df = pd.DataFrame(rows, columns=headers)
# graph_df

# %%
# node_df = pd.concat([
#     graph_df[['cause','source']].rename(columns={'cause':'node','source':'sources'}),
#     graph_df[['effect','source']].rename(columns={'effect':'node','source':'sources'})
# ],axis=0).drop_duplicates().reset_index(drop=True)
# node_df

# %%
# graph_df.to_csv(os.path.join(graph_folder,'graph.csv'), index=False, encoding='utf-8-sig')
# node_df.to_csv(os.path.join(graph_folder,'node_df.csv'), index=False, encoding='utf-8-sig')

# %%
from simcse import SimCSE
from sklearn.cluster import KMeans

model = SimCSE("princeton-nlp/sup-simcse-bert-base-uncased")
sentences = list(data['cause_action_rem'])+list(data['effect_action_rem'])
sentences = [re.sub('[MASK]','',i) for i in sentences]
embeddings = model.encode(sentences)
print(embeddings.shape)

kmeans = KMeans(N_TOPICS)
kmeans_output = kmeans.fit(embeddings)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 202/202 [14:10<00:00,  4.21s/it]
# torch.Size([12874, 768])

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

### 4. Select Topic Words from Clusters
def _preprocess_text(documents):
    """ Basic preprocessing of text
    Steps:
        * Lower text
        * Replace \n and \t with whitespace
        * Only keep alpha-numerical characters
    """
    cleaned_documents = [doc.lower() for doc in documents]
    cleaned_documents = [doc.replace("\n", " ") for doc in cleaned_documents]
    cleaned_documents = [doc.replace("\t", " ") for doc in cleaned_documents]

    return cleaned_documents
    
# _update_topic_size
documents = pd.DataFrame({
    'Topic': list(kmeans_output.labels_),
    'Document': sentences
})
sizes = documents.groupby(['Topic']).count().sort_values("Document", ascending=False).reset_index()
topic_sizes = dict(zip(sizes.Topic, sizes.Document))

# _extract_topics
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})

# _weighting_words
concatenated_documents = _preprocess_text(documents_per_topic.Document.values)
origin_documents = _preprocess_text(documents.Document.values)

# count the words in a cluster
vectorizer_model = CountVectorizer()
vectorizer_model.fit(concatenated_documents)
words = vectorizer_model.get_feature_names()
# k * vocab
X_per_cluster = vectorizer_model.transform(concatenated_documents)
# D * vocab
X_origin = vectorizer_model.transform(origin_documents)
# Out:
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# https://github.com/hyintell/topicx/blob/56b03e5e3bfcdae9ea47d65f82c2a15be0f649a8/baselines/cetopic/tfidf_idfi.py#L8
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import normalize
import numpy as np
import pandas as pd
import scipy.sparse as sp


class TFIDF_IDFi(TfidfTransformer):

    def __init__(self, X_per_cluster, X_origin, all_documents, *args, **kwargs):
        print('====== Using TFIDF_IDFi ======')
        super().__init__(*args, **kwargs)
        self.X_per_cluster = X_per_cluster
        self.X_origin = X_origin
        self.all_documents = all_documents
        
    
    def score(self):
        
        self._global_tfidf = self.fit_transform(self.X_origin)
        
        global_df = pd.DataFrame(self._global_tfidf.toarray())
        global_df['Topic'] = self.all_documents.Topic
        
        avg_global_df = global_df.groupby(['Topic'], as_index=False).mean()
        avg_global_df = avg_global_df.drop('Topic', 1)
        self._avg_global_tfidf = avg_global_df.values
        
        local_tfidf_transformer = TfidfTransformer()
        local_tfidf_transformer.fit_transform(self.X_per_cluster)
        self._idfi = local_tfidf_transformer.idf_
        
        scores = self._avg_global_tfidf * self._idfi
        scores = normalize(scores, axis=1, norm='l1', copy=False)
        scores = sp.csr_matrix(scores)

        return scores 
    

def _top_n_idx_sparse(matrix, n):
    """ Return indices of top n values in each row of a sparse matrix
    Retrieved from:
        https://stackoverflow.com/questions/49207275/finding-the-top-n-values-in-a-row-of-a-scipy-sparse-matrix
    Args:
        matrix: The sparse matrix from which to get the top n indices per row
        n: The number of highest values to extract from each row
    Returns:
        indices: The top n indices per row
    """
    indices = []
    for le, ri in zip(matrix.indptr[:-1], matrix.indptr[1:]):
        n_row_pick = min(n, ri - le)
        values = matrix.indices[le + np.argpartition(matrix.data[le:ri], -n_row_pick)[-n_row_pick:]]
        values = [values[index] if len(values) >= index + 1 else None for index in range(n)]
        indices.append(values)
    return np.array(indices)


def _top_n_values_sparse(matrix, indices):
    """ Return the top n values for each row in a sparse matrix
    Args:
        matrix: The sparse matrix from which to get the top n indices per row
        indices: The top n indices per row
    Returns:
        top_values: The top n scores per row
    """
    top_values = []
    for row, values in enumerate(indices):
        scores = np.array([matrix[row, value] if value is not None else 0 for value in values])
        top_values.append(scores)
    return np.array(top_values)


# self.word_select_method == 'tfidf_idfi'
scores = TFIDF_IDFi(X_per_cluster, X_origin, documents).score()
# _extract_words_per_topic
labels = sorted(list(topic_sizes.keys()))
indices = _top_n_idx_sparse(scores, 30)
scores = _top_n_values_sparse(scores, indices)
sorted_indices = np.argsort(scores, 1)
indices = np.take_along_axis(indices, sorted_indices, axis=1)
scores = np.take_along_axis(scores, sorted_indices, axis=1)
topics = {label: [(words[word_index], score)
                  if word_index and score > 0
                  else ("", 0.00001)
                  for word_index, score in zip(indices[index][::-1], scores[index][::-1])
                  ]
          for index, label in enumerate(labels)}
topics = {label: values[:TOP_N_WORDS] for label, values in topics.items()}

TOP_N_KEYWORDS = 3
topic2keywords = {}

for k,v in topics.items():
    print('\n', k)
    print(v)
    if topic_sizes[k]==1:
        topic2keywords[k] = documents[documents['Topic']==k]['Document'].iloc[0]
    else:
        topic2keywords[k] = '_'.join([i[0] for i in v[:TOP_N_KEYWORDS]])

topic2keywords
# Out:
# ====== Using TFIDF_IDFi ======
# C:\Users\effbl\anaconda3\envs\cre\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#  0
# [('assets', 0.27795146534190174), ('leveraged', 0.1712575517428647), ('injecting', 0.15509192313045295), ('inject', 0.11766217957318832), ('what', 0.06274442577756019), ('yet', 0.0604710068381538), ('capital', 0.056264913755370405), ('another', 0.05220860051517357), ('into', 0.03442346779004136), ('of', 0.00702269094998379), ('to', 0.004901774585309337), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
#
#  1
# [('827', 0.14094864034454707), ('30', 0.08335332163332057), ('units', 0.0824124170717943), ('drove', 0.08114218964841453), ('77', 0.06875417272593642), ('29', 0.06613785537457002), ('increased', 0.059285881505200116), ('sales', 0.052785131906086004), ('once', 0.05205932764142577), ('again', 0.0482819395263377), ('uvs', 0.0431224837628996), ('volume', 0.042381952905026506), ('sold', 0.03664848698937182), ('growth', 0.02700892513992014), ('million', 0.024111941410944433)]
#
#  2
# [('', 1e-05), ('cut', 0.07069405793322787), ('plan', 0.06338584593453145), ('50', 0.03931307962612583), ('100', 0.03626766670041322), ('global', 0.03328157766646981), ('vehicles', 0.03202148990277198), ('150', 0.03142252115492044), ('by', 0.029841606526276133), ('production', 0.024200222095908018), ('its', 0.02255627029555297), ('850', 0.021628579903496363), ('sink', 0.0192122504737871), ('output', 0.018732689444831155), ('7203', 0.01834954073491683)]
#
#  3
# [('affordable', 0.0920937999839122), ('displays', 0.09116806182897547), ('superbike', 0.0814123603205607), ('minicar', 0.06262096330860224), ('cater', 0.06059347585695297), ('segments', 0.05522454514839795), ('sensitive', 0.049970893684111464), ('smart', 0.047335227994918724), ('cars', 0.04082556919010312), ('premium', 0.03987494910034771), ('low', 0.03803006328256056), ('segment', 0.034554387434663804), ('prices', 0.03406339438613069), ('help', 0.03307015521502368), ('keep', 0.03302624792020145)]
#
#  4
# [('acquire', 0.19349132918143228), ('decarbonised', 0.15776475601399848), ('transaction', 0.1113238952977499), ('talks', 0.08443410055646913), ('stake', 0.08250739642522162), ('lithium', 0.07722620273338572), ('materials', 0.0671934198875921), ('business', 0.04520297931193718), ('battery', 0.039882213326872445), ('company', 0.03543318082754534), ('an', 0.027357370659668905), ('in', 0.02508432034115747), ('be', 0.021248655778634235), ('to', 0.01856053727068951), ('of', 0.008587575915469013)]
('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
#
#  101
# [('crunch', 0.2796915600691038), ('chip', 0.1442139793822179), ('plagued', 0.12162433777479768), ('universal', 0.1032024728993875), ('hurt', 0.09539659005766649), ('continuing', 0.06330939427768531), ('challenge', 0.05501265854968781), ('by', 0.04117054563155683), ('global', 0.02889373906343409), ('industry', 0.0259386639180052), ('supply', 0.025673806998971215), ('the', 0.0115728642623203), ('to', 0.004299387115165825), ('', 1e-05), ('', 1e-05)]
#
#  102
# [('consider', 0.2005373565778238), ('we', 0.12485140335532499), ('works', 0.07973006114822774), ('context', 0.06775176150122048), ('must', 0.06494559395425141), ('thought', 0.06477503769590644), ('cover', 0.05839350911484067), ('too', 0.05283048731007482), ('would', 0.04359648860924076), ('what', 0.04306314197246155), ('need', 0.03521968547675656), ('said', 0.03453358601894632), ('that', 0.03033387542930053), ('some', 0.024152127762791034), ('have', 0.019226531557104833)]
#
#  103
# [('semiconductor', 0.22484589191530205), ('chips', 0.1772076073716673), ('shortage', 0.1710687658832075), ('chip', 0.06479087121906883), ('procurement', 0.05520644056757789), ('sudden', 0.05339546871785413), ('stable', 0.04594646663814507), ('uncertainty', 0.0409655730913551), ('ongoing', 0.03794536463045892), ('now', 0.027112221781511316), ('expected', 0.026171903974625106), ('global', 0.019288534854753323), ('over', 0.016049276887553206), ('of', 0.015582431585711955), ('the', 0.011523064480313176)]
#
#  104
# ...
#  539: 'president_wi_arrived',
#  540: 'frican_by_outh',
#  541: 'signed_euro_italian',
#  542: 'dealerships_stations_installing',
#  543: 'war_wars_battlefield',
#  544: 'wealth_glamor_ambitions',
#  545: 'fuel_hybrids_cars',
#  546: 'hybrids_category_included',
#  547: 'factories_stops_pause',
#  548: 'to carry out docking and orbit experiments .',
#  549: 'independently_developed_seamless',
#  550: 'has_this_accrued',
#  551: "underperforming a [] drop on [] ' s blue chip index ( . FTIB ) in a [] crisis - hit trading session",
#  552: 'relaxed_tightened_rules',
#  553: 'stoppages_productivity_impacts',
#  554: 'qure_ghosn_azgar',
#  555: '49_51_members',
#  556: 'detailed_monitoring_feedback',
#  557: 'merged_earlier_year',
#  558: 'batteries_cost_earn',
#  559: 'electric_vehicles_growing',
#  560: 'objective_competitiveness_policies',
#  561: 'record_be_will',
#  562: 'technology_technologies_tech',
#  563: 'goal__',
#  564: 'vertical_develops_integrations',
#  565: 'crisis_19_covid',
#  566: 'investigation_investigations_sexual',
#  567: 'address_issue_crisisin',
#  568: 'several_suspend_suppliers',
#  569: 'financing_programmes_acquisition',
#  570: 'requirement_meet_requirements',
#  571: 'slash_plans_early',
#  572: 'crackdown_caught_intrusions',
#  573: 'shortfalls_mitigated_supplement',
#  574: 'wife_daughter_requested',
#  575: 'boost_factories_cosmetics',
#  576: 'battery_manufacturing_large',
#  577: 'airbag_inflator_activation',
#  578: 'tsunami_earthquake_heavily',
#  579: 'rates_higher_required',
#  580: 'top_off_it',
#  581: 'cars_mart_generation',
#  582: 'jobs_manufacturing_centralised',
#  583: 'cannot_flights_back',
#  584: 'dpc_stage_strategy',
#  585: 'expecting the company will be able to maintain a strong financial profile following record first - half results .',
#  586: 'reflect lower than normal vehicle output in [] at the moment',
#  587: 'byd_however_',
#  588: 'months_merger_post',
#  589: 'feasibility_wouldn_we',
#  590: 'players_pairing_compete',
#  591: 'fair_definitely_even',
#  592: 'maize_area_varieties',
#  593: 'with the Indian unit',
#  594: 'exclusively_wheels_tyres',
#  595: '11th_civic_generation',
#  596: 'revised_version_updated',
#  597: 'car_sedan_passenger',
#  598: 'model_navigator_retool',
#  599: 'booming_automobile_popularity',
#  600: 'bubble_site_live',
#  601: 'lack_components_this',
#  602: 'chassis_realistic_narrow',
#  603: 'agility_determination_needed',
#  604: 'tellantis_currently_includes',
#  605: 'stake_cut_its',
#  606: 'online_flurry_intensified',
#  607: 'declined_comment_talks',
#  608: 'flexible_efficient_organisation',
#  609: 'everything_did_doing',
#  610: 'sales_slight_outpaced',
#  611: 'heavy_rainfall_rain',
#  612: 'coal_coking_tonnes',
#  613: 'baojun_uv_510',
#  614: 'restricting_rollout_discharge',
#  615: 'taxes_attract_much',
#  616: 'congestion_ports_port',
#  617: 'prices_weigh_rising',
#  618: 'frugality_enjoy_smart',
#  619: 'extensive_expertise_career',
#  620: 'welded_china_zero',
#  621: 'xi_signalled_diplomacy',
#  622: 'offer_wants_calls',
#  623: 'sense_doesn_make',
#  624: '[] ’ s strict monitoring and restrictions on travel',
#  625: 'froze_ilan_tellantis',
#  626: 'tastes_suit_local',
#  627: 'carmakers_revisiting_detuned',
#  628: 'Every new hire is an integral part of our [] team',
#  629: 'any cases are found .',
#  630: 'dominant_li_ion',
#  631: 'that more than 1 . 3 million people die each year',
#  632: 'statement_said_all',
#  633: 'cat_ora_good',
#  634: 'overwhelming_did_enough',
#  635: 'welcomes_permit_vital',
#  636: 'ideal_timing_interval',
#  637: 'lockdown_city_initiated',
#  638: 'startups_partnering_firms',
#  639: 'profile_highest_punch',
#  640: 'speed_top_overtaking',
#  641: 'june__',
#  642: 'nickel_reserves_world',
#  643: 'coronavirus_outbreak_curb',
#  644: 'correspondent_briefed_hosted',
#  645: 'initiatives_pg_jumpstart',
#  646: 'cabin_spacious_impreza',
#  647: 'batteries_electric_ev',
#  648: 'Following a pledge last year to no longer use the [] name , the Chinese - owned company will use the [] trademark for cars it produces',
#  649: 'significant_portion_share',
#  650: 'lockdowns_lockdown_curbs',
#  651: 'swiftly_flare_ups',
#  652: 'fourth_world_largest',
#  653: 'supply_improves_situation',
#  654: 'brakes_ceramic_hold',
#  655: 'ruined_lives_extreme',
#  656: 'overcapacity_tackle_hurdle',
#  657: 'variants_variant_sub',
#  658: '665_710m_thb23bn',
#  659: 'restoring_damaged_fire',
#  660: 'prices_fuel_rising',
#  661: 'faulty_japanese_immobilizers',
#  662: 'otors_general_otor',
#  663: 'green_energy_consumption',
#  664: 'pacific_lashed_crisscrossed',
#  665: 'prices_priced_higher',
#  666: 'incentives_benefit_maximize',
#  667: 'wheels_riskthe_badly',
#  668: 'webasto_location_where',
#  669: 'hr_retains_spot',
#  670: 'spare_bargaining_parts',
#  671: '10_closer_member',
#  672: 'actions_announcements_these',
#  673: 'nio_currently_best',
#  674: 'avoid_delay_late',
#  675: 'boycott_lotte_triggering',
#  676: 'yuan_interpretation_true',
#  677: 'repeat_issuers_green',
#  678: 'credits_generate_affiliated',
#  679: 'outh_orean_leasing',
#  680: 'bonuses_deduct_default',
#  681: 'business_improve_performance',
#  682: 'ice_hvo100_dense',
#  683: 'embrace_little_successors',
#  684: 'unlikely_till_worsen',
#  685: 'innovation_technologies_improve',
#  686: 'remote_work_workload',
#  687: 'nab_tackle_them',
#  688: 'retooling_plants_plant',
#  689: 'tourism_exports_recovery',
#  690: 'costs_adds_comes',
#  691: 'runway_veering_closed',
#  692: 'we hope you will accept our invitation to open the way to the future together !',
#  693: 'cheap_mass_inexpensive',
#  694: 'enabling_whilst_posting',
#  695: 'transparent_be_to',
#  696: 'volatility_to_',
#  697: 'eat_replace_not',
#  698: 'criminal_300_penalty',
#  699: 'automakers_supply_serve',
#  700: 'electrification_offerings_signifying',
#  701: 'spend_billion_to',
#  702: 'hundreds_carry_cost',
#  703: 'stresses_jitters_',
#  704: 'riders_policyholders_roadside',
#  705: 'masks_workplaces_autoworkers',
#  706: 'supplier_vertically_integrating',
#  707: 'chain_supply_diversification',
#  708: 'chains_backlog_chaos',
#  709: 'apps_removed_addresses',
#  710: 'safety_improves_service',
#  711: 'show_auto_showcased',
#  712: 'stabilise_society_economy',
#  713: 'pioneer_heightening_urgency',
#  714: 'utomakers_spending_billions',
#  715: 'ambitions_loftier_aspirations',
#  716: 'indian_crack_slump',
#  717: 'north_merican_remind',
#  718: 'inclusion_asked_ppointment',
#  719: 'risks_risky_assets',
#  720: 'wid_get_go',
#  721: 'to escape being trapped inside the factory amid rumors that workers on the floor that day tested positive for COVID .',
#  722: 'repair_procedures_servicing',
#  723: 'month_692_259',
#  724: 'cloud_computing_connectivity',
#  725: 'bikes_drifting_telecommuting',
#  726: 'up [] to criticism',
#  727: 'plants_closing_shut',
#  728: 'weight_reduce_reducing',
#  729: 'unspecified violations of its rules .',
#  730: 'fail_setbacks_company',
#  731: 'transmissible_battling_contain',
#  732: 'units_099_255',
#  733: 'grappling_distress_hardline',
#  734: 'privacy_v2x_protection',
#  735: '92_grew_171',
#  736: 'output_plants_reduce',
#  737: 'toyota_meanwhile_archtecture',
#  738: 'tightness in several materials',
#  739: 'gather_data_mined',
#  740: 'representation_inductive_segment',
#  741: '63_fell_sales',
#  742: 'ev_producer_charger',
#  743: 'pitch_destination_investment',
#  744: 'population_growing_rapidly',
#  745: 'without a lot of places',
#  746: 'digital_reassessment_infrastructure',
#  747: 'overcome_obstacle_curb',
#  748: '_400_51',
#  749: 'environmental_opponent_vocal',
#  750: 'things_well_go',
#  751: 'but is also open to forming new partnerships',
#  752: 'the Vitara Brezza',
#  753: 'speak_authorized_reporters',
#  754: ', we are the only creator of redefined electric icons fully capable of ramping up production',
#  755: 'mobility_sustainable_shared',
#  756: 'tesla_currently_projection',
#  757: 'peers_burden_facing',
#  758: 'we can ’ t complain !',
#  759: 'developments_these_to',
#  760: 'only_few_still',
#  761: 'estimated_figures_value',
#  762: 'global_company_globally',
#  763: 'discounts_dealers_restricting',
#  764: 'return_faster_to',
#  765: 'tires_export_increases',
#  766: 'once booked , a swipe of your ID card or passport at the ticket gates is all you need to travel . "',
#  767: 'lost_credibility_confidence',
#  768: 'trade_barriers_huge',
#  769: '… no .',
#  770: 'rice_eed_breeding',
#  771: 'cases_case_detected',
#  772: 'shutdowns_rolling_plants',
#  773: 'utocar_utox_also',
#  774: 'expedite_construction_project',
#  775: 'decision_took_chosen',
#  776: 'ay_fixed_deepen',
#  777: 'exciting_updates_rather',
#  778: 'store_assess_economies',
#  779: 'size_proportions_amount',
#  780: 'sixth_slid_since',
#  781: 'hr_generation_new',
#  782: 'talent_infuse_provides',
#  783: 'fire_harness_risk',
#  784: 'list_features_long',
#  785: 'programs_pilot_unmanned',
#  786: 'quickly_boldly_thinking',
#  787: '( [] did not make a projection for [] in its [] outlook',
#  788: 'shut_down_its',
#  789: 'consortium_nine_included',
#  790: 'numbers_confirming_enough',
#  791: 'shortages_tackle_staff',
#  792: 'region_regions_province',
#  793: 'joint_venture_dissolve',
#  794: 'european_penetrating_eu',
#  795: 'link_rail_wants',
#  796: 'probe_sponsored_by',
#  797: 'cyberattack_suspected_hacker',
#  798: 'ipo_celebrate_completed',
#  799: 'chinese_dongfeng_stake',
#  800: 'olympics_commercials_related',
#  801: '__',
#  802: 'sold_year_amounted',
#  803: 'crimes_manipulating_accused',
#  804: 'reserve_cash_',
#  805: 'drinks_retain_position',
#  806: 'skylines_long_been',
#  807: 'urged_lobby_lobbying',
#  808: 'chip_covid_shortages',
#  809: 'industry_inching_influence',
#  810: 'taking Wall treet by surprise .',
#  811: 'gw_invested_also',
#  812: 'shares_listed_hong',
#  813: 'to replace a wheel hub bolt .',
#  814: 'Targeting higher skies',
#  815: 'electrified_volts_powertrain',
#  816: 'venture__',
#  817: 'unprecedented_difficulties_difficult',
#  818: 'trucks_securing_teamed',
#  819: 'food_medical_complained',
#  820: 'growing_afoot_motoring',
#  821: 'motorsports_peek_seasons',
#  822: 'losses_massive_loss',
#  823: 'headquarters_head_waiting',
#  824: 'delegation_vietnamese_events',
#  825: 'wheelbase_mm_longer',
#  826: 'zero_net_emissions',
#  827: 'vitara_platform_configuration',
#  828: 'option_choice_no',
#  829: 'pick_trucks_tundra',
#  830: 'mobility_firming_horizon',
#  831: 'hydrogen_oxygen_reaction',
#  832: 'steeply_waits_expensive',
#  833: 'greenhouse_emit_noise',
#  834: 'rules_new_spurred',
#  835: 'semiconductors_curbs_covid',
#  836: 'disruption_insulate_troubleshoot',
#  837: 'metal_reputational_cost',
#  838: 'patients_biosimilar_infliximab',
#  839: 'demanded_must_corporation',
#  840: 'hevs_strong_spectrum',
#  841: 'uncertain_affairs_struggles',
#  842: 'However , as one forwarding contact told The Loadstar this week , the lower rates were “ academic ”',
#  843: 'lost_units_million',
#  844: 'gdp_higher_with',
#  845: 'restrictions_relaxed_restrictive',
#  846: 'the Games opening there in just over three weeks and [] ’ s national pride on the line',
#  847: 'byd_chinese_agreed',
#  848: 'chipmaker_globalfoundries_hands',
#  849: 'automation_driving_automated',
#  850: 'Yet its bold presence belies an uncomfortable truth',
#  851: 'announced_partnered_ce',
#  852: 'undermine_transition_governments',
#  853: 'roof_arched_tall',
#  854: 'monetary_signals_easing',
#  855: 'continuing_month_shortage',
#  856: 'inequality_merely_transitional',
#  857: "##a , the world ' s third - biggest oil importer , has increased purchases of Russian crude in recent months",
#  858: 'weighed_activity_economic',
#  859: 'fires_fire_hot',
#  860: 'hydrogen_ultanate_jointly',
#  861: 'enough_done_was',
#  862: 'capacity_offload_expand',
#  863: 'local_authorities_clearance',
#  864: 'enter_public_pedestrians',
#  865: 'barrier_affordability_poor',
#  866: 'factors_these_confluence',
#  867: 'strain_struggling_suppliers',
#  868: 'respect_firmly_rules',
#  869: 'second_economy_world',
#  870: 'chip_shortage_global',
#  871: 'billion_raised_last',
#  872: 'bvi_emission_vi',
#  873: 'sell_realised_them',
#  874: ', which underscores the importance of table tennis in []',
#  875: 'pldb_database_future',
#  876: 'geopolitical_inflation_concerns',
#  877: 'shares_shareholders_holding',
#  878: 'powertrain_electricity_using',
#  879: 'growth_growing_digit',
#  880: 'to working with the Indian government',
#  881: 'reason_why_wanted',
#  882: 'outbreak_contain_covid',
#  883: 'uv_uvs_premium',
#  884: 'halting_advised_ports',
#  885: 'subsidies_expire_extending',
#  886: 'confined_homes_residents',
#  887: 'development_ev_ramping',
#  888: 'charging_infrastructure_pushing',
#  889: 'profit_reported_ended',
#  890: 'Rivian',
#  891: 'to optimize audio .',
#  892: 'approval_reject_fdi',
#  893: 'pollution_combat_air',
#  894: 'government_supplement_clunkers',
#  895: 'iconic_classic_converted',
#  896: 'tight_shortfall_pent',
#  897: 'mortgages_refusal_pay',
#  898: 'fleet_navy_consolidate',
#  899: 'employee_salaries_adjusting',
#  900: 'careful_afraid_break',
#  901: 'populations_pension_labor',
#  902: 'odi_emphasis_placed',
#  903: 'issues_usually_problems',
#  904: 'japanese_drinks_strength',
#  905: 'driver_rx_pilot',
#  906: 'order_reversal_move',
#  907: 'released_convicted_arrested',
#  908: 'lowest_things_along',
#  909: 'income_falls_net',
#  910: 'engine_engines_powering',
#  911: 'papers_preliminary_filed',
#  912: 'energy_consumption_save',
#  913: 'subsidise_outlawed_import',
#  914: 'foreign_investors_investment',
#  915: 'sights_ahead_looking',
#  916: 'island_southernmost_main',
#  917: '50_venture_joint',
#  918: 'acceptance_prefers_encouraging',
#  919: 'container_ships_shipyards',
#  920: 'struggling_struggle_producers',
#  921: 'xuv300_indian_ahindra',
#  922: 'everyone_allgoers_',
#  923: 'chinese_based_partner',
#  924: 'final_country_that',
#  925: 'losing_jobs_workforce',
#  926: 'acquisitions_flex_warehousing',
#  927: 'together_work_government',
#  928: 'powered_cast_aside',
#  929: 'consumers_consumer_foster',
#  930: 'intra_consolidation_trips',
#  931: 'workers_don_severance',
#  932: 'sales_revenue_reach',
#  933: 'drop_compares_particular',
#  934: 'hybrid_attaining_solution',
#  935: 'checking_falsely_certified',
#  936: 'chinese_brands_advantage',
#  937: 'jimny_manufacture_uv',
#  938: 'third_largest_behind',
#  939: 'director_who_also',
#  940: 'thousand_80_units',
#  941: '40__290',
#  942: 'slumped_nd_fiscal',
#  943: 'intellectual_property_ip',
#  944: 'surprise_wouldn_hand',
#  945: 'byd_materially_undervalued',
#  946: 'notify_regulations_supplemental',
#  947: 'a cracker',
#  948: 'problem_solve_fix',
#  949: 'tricky_wrong_issues',
#  950: 'pulled_suspended_halted',
#  951: 'labor_tightest_tight',
#  952: 'components_dependable_vital',
#  953: 'month_year_drop',
#  954: ', calling it a Commodore was a bridge too far',
#  955: 'manufacturing_sophisticated_gaining',
#  956: 'strict_lockdowns_lockdown',
#  957: 'dng_underpinned_low',
#  958: 'chinese_thailand_brands',
#  959: 'oppose this corporate and union conspiracy',
#  960: 'range_rwd_ach',
#  961: 'sticking_annual_target',
#  962: 'prior_il_mandatory',
#  963: 'project_proponents_one',
#  964: 'engines_smaller_continue',
#  965: 'dpc_turnaround_improvement',
#  966: 'wall_briefly_currently',
#  967: 'delays_delay_lists',
#  968: 'arrive_arrived_prospects',
#  969: 'instantly killing both test officials inside .',
#  970: 'market_regional_brisk',
#  971: 'rushed_forward_passersby',
#  972: 'anonymity_sought_condition',
#  973: 'model_models_local',
#  974: 'xr_xle_',
#  975: 'budding_less_collectively',
#  976: 'free_enhancements_receives',
#  977: 'ubaru_uzuki_pools',
#  978: 'drivers_using_stop',
#  979: 'to secure the future of the great community in []',
#  980: 'adjust_production_clock',
#  981: 'course_come_there',
#  982: 'merica_unlike_though',
#  983: 'affects_kinds_restrictions',
#  984: ', but several other publications are sharing it seriously ,',
#  985: 'shipped_defend_channel',
#  986: 'issue_could_problem',
#  987: 'talks_negotiations_successful',
#  988: 'our ancestors dined mostly on mammoth and raw plants',
#  989: 'affiliate_amsung_di',
#  990: '100_review_ordered',
#  991: 'comparisons_wholesale_glanza',
#  992: 'german_ecurity_might',
#  993: 'efficiently_important_control',
#  994: 'posted_revenue_rise',
#  995: 'xiaomi__',
#  996: 'comfortable_driveability_experience',
#  997: 'that car companies should consider holding larger stockpiles of chips',
#  998: 'companies_competed_competition',
#  999: 'measures_urgent_needed',
#  ...}

# %%
topic_id = 10
print(topic2keywords[topic_id])
documents[documents['Topic']==topic_id]
# Out:
# chain_supply_disruptions
#        Topic                                           Document
# 2352      10  potential supply chain disruptions as a result...
# 3111      10   a few ( unrelated ) supply - chain disruptions .
# 5502      10  had it not been for lingering supply chain woes .
# 6058      10           : [] lockdown may disrupt supply chain ,
# 6785      10  , and supply chains look unlikely to return to...
# 7420      10  , there may be disruptions in the supply chain...
# 7687      10  ; reports suggest there could be a shortage of...
# 12622     10  which can lead to supply shortages in case of ...

# %%
documents['Keywords'] = documents['Topic'].apply(lambda x: topic2keywords[int(x)])
documents
# Out:
#        Topic                                           Document  \
# 0        693   to get similar to the low cost available in [] .
# 1       1246     a possible power shortage in the coming winter
# 2       3114                           you do things the [] way
# 3        832          cost of vehicles does not go up steeply .
# 4        766  once booked , a swipe of your ID card or passp...
# ...      ...                                                ...
# 12869    123                                       ” OURCE : CE
# 12870   2489  ” topping work at the factory would harm tella...
# 12871   1467  ” The slowdown in [] is likely to have knock -...
# 12872   3273  ” don ’ t expect to see it on ustralian street...
# 12873    769                                             … no .
#
#                                                 Keywords
# 0                                 cheap_mass_inexpensive
# 1                                  winter_severely_finns
# 2                                        sort_things_you
# 3                                steeply_waits_expensive
# 4      once booked , a swipe of your ID card or passp...
# ...                                                  ...
# 12869                                     ource_arcus_ce
# 12870                                harm_worker_violate
# 12871                              sharply_slowed_second
# 12872  ” don ’ t expect to see it on ustralian street...
# 12873                                             … no .
#
# [12874 rows x 3 columns]

# %%
documents.to_csv(os.path.join(graph_folder, 'node_topics.csv'), index=False, encoding='utf-8-sig')

# %%
tmp = copy(data)
tmp['cause_topic'] = list(documents['Topic'])[:int(len(documents)/2)]
tmp['effect_topic'] = list(documents['Topic'])[int(len(documents)/2):]
tmp
# Out:
#                                                  effect  source  support  \
# 0     " A U . S . facility would need a better U . S...   f-476        1
# 1     " As a result of great uncertainties , Finns s...  f-4849        2
# 2               " Being profitable in India is possible    f-29        1
# 3     " But real challenge is bringing in maximum sa...   f-123        1
# 4     " China ' s high - speed lines are ruthlessly ...  f-5198        1
# ...                                                 ...     ...      ...
# 6432                                    ” SOURCE : ACEA  f-1804        1
# 6433  ” Stopping work at the factory would harm Stel...   f-808        1
# 6434  ” The slowdown in China is likely to have knoc...  f-4742        1
# 6435  ” don ’ t expect to see it on Australian stree...  f-4473        1
# 6436                                             … no .  f-4236        1
#
#                                                evidence  \
# 0     "A U.S. facility would need a better U.S. supp...
# 1     "As a result of great uncertainties, Finns sho...
# 2     "Being profitable in India is possible if you ...
# 3     "But real challenge is bringing in maximum saf...
# 4     "China's high-speed lines are ruthlessly effic...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433  We have people in Russia and we love them also...
# 6434  “This will lock China substantially out of the...
# 6435  While the revealed car is “production ready” d...
# 6436  Well, it seems highly unlikely that GM Special...
#
#                                                   cause  \
# 0     to get similar to the low cost available in Ch...
# 1        a possible power shortage in the coming winter
# 2                           you do things the India way
# 3             cost of vehicles does not go up steeply .
# 4     once booked , a swipe of your ID card or passp...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433   We have people in Russia and we love them also .
# 6434  “ This will lock China substantially out of th...
# 6435  VW prioritises markets with stricter emissions...
# 6436  Well , it seems highly unlikely that GM Specia...
#
#                                            cause_action  \
# 0     to get similar to the low cost available in [L...
# 1        a possible power shortage in the coming winter
# 2                      you do things the [LOCATION] way
# 3             cost of vehicles does not go up steeply .
# 4     once booked , a swipe of your ID card or passp...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433  We have people in [LOCATION] and we love them ...
# 6434  “ This will lock [LOCATION] substantially out ...
# 6435  [ORGANIZATION] prioritises markets with strict...
# 6436  Well , it seems highly unlikely that [ORGANIZA...
#
#                                           effect_action  \
# 0     " A [LOCATION] facility would need a better [L...
# 1     " As a result of great uncertainties , Finns s...
# 2          " Being profitable in [LOCATION] is possible
# 3     " But real challenge is bringing in maximum sa...
# 4     " [LOCATION] ' s high - speed lines are ruthle...
# ...                                                 ...
# 6432                                    ” SOURCE : ACEA
# 6433  ” Stopping work at the factory would harm Stel...
# 6434  ” The slowdown in [LOCATION] is likely to have...
# 6435  ” don ’ t expect to see it on Australian stree...
# 6436                                             … no .
#
#                                        cause_action_rem  \
# 0     to get similar to the low cost available in [M...
# 1        a possible power shortage in the coming winter
# 2                          you do things the [MASK] way
# 3             cost of vehicles does not go up steeply .
# 4     once booked , a swipe of your ID card or passp...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433   We have people in [MASK] and we love them also .
# 6434  “ This will lock [MASK] substantially out of t...
# 6435  [MASK] prioritises markets with stricter emiss...
# 6436  Well , it seems highly unlikely that [MASK] wo...
#
#                                       effect_action_rem  \
# 0     " A [MASK] facility would need a better [MASK]...
# 1     " As a result of great uncertainties , Finns s...
# 2              " Being profitable in [MASK] is possible
# 3     " But real challenge is bringing in maximum sa...
# 4     " [MASK] ' s high - speed lines are ruthlessly...
# ...                                                 ...
# 6432                                    ” SOURCE : ACEA
# 6433  ” Stopping work at the factory would harm Stel...
# 6434  ” The slowdown in [MASK] is likely to have kno...
# 6435  ” don ’ t expect to see it on Australian stree...
# 6436                                             … no .
#
#                                            evidence_ner  \
# 0     [(``, O), (A, O), (U.S., LOCATION), (facility,...
# 1     [(``, O), (As, O), (a, O), (result, O), (of, O...
# 2     [(``, O), (Being, O), (profitable, O), (in, O)...
# 3     [(``, O), (But, O), (real, O), (challenge, O),...
# 4     [(``, O), (China, LOCATION), ('s, O), (high-sp...
# ...                                                 ...
# 6432  [(Measures, O), (will, O), (also, O), (need, O...
# 6433  [(We, O), (have, O), (people, O), (in, O), (Ru...
# 6434  [(“, O), (This, O), (will, O), (lock, O), (Chi...
# 6435  [(While, O), (the, O), (revealed, O), (car, O)...
# 6436  [(Well, O), (,, O), (it, O), (seems, O), (high...
#
#                                             cause_store  \
# 0     {'ORGANIZATION': [], 'LOCATION': ['China'], 'D...
# 1     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 2     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 3     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 4     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# ...                                                 ...
# 6432  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 6433  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 6434  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...
# 6435  {'ORGANIZATION': ['VW'], 'LOCATION': [], 'DATE...
# 6436  {'ORGANIZATION': ['GM Special Vehicles'], 'LOC...
#
#                                            effect_store  cause_topic  \
# 0     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...          693
# 1     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...         1246
# 2     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...         3114
# 3     {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...          832
# 4     {'ORGANIZATION': [], 'LOCATION': ['China'], 'D...          766
# ...                                                 ...          ...
# 6432  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...          419
# 6433  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...         1438
# 6434  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...         3126
# 6435  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...           56
# 6436  {'ORGANIZATION': [], 'LOCATION': [], 'DATE': [...         3625
#
#       effect_topic
# 0              216
# 1             1246
# 2             2090
# 3              710
# 4             2779
# ...            ...
# 6432           123
# 6433          2489
# 6434          1467
# 6435          3273
# 6436           769
#
# [6437 rows x 14 columns]

# %%
graph_folder = r"D:\66 CausalMap\SciLit_CausalMap\visualization\mir_nerclust"
headers = ['cause','effect','source','support','evidence']

rows = []
for i,row in tmp.iterrows():
    rows.append([
        str(int(row.cause_topic))+'>>'+topic2keywords[int(row.cause_topic)],
        str(int(row.effect_topic))+'>>'+topic2keywords[int(row.effect_topic)],
        str(row.source),
        int(row['support']),
        str(row.cause)+' --> '+ str(row.effect) + ';' + str(row.evidence)
    ])
graph_df = pd.DataFrame(rows, columns=headers)

# show only reliable info
graph_df[(graph_df['support']>1) | ((graph_df['cause'].str.contains('>>', na=True)) & (graph_df['effect'].str.contains('>>', na=True)))]
# Out:
#                                                   cause  \
# 0                           693>>cheap_mass_inexpensive
# 1                           1246>>winter_severely_finns
# 2                                 3114>>sort_things_you
# 3                          832>>steeply_waits_expensive
# 4     766>>once booked , a swipe of your ID card or ...
# ...                                                 ...
# 6432                              419>>demand_meet_user
# 6433                              1438>>friends_love_we
# 6434                     3126>>2024_break_substantially
# 6435                56>>regulations_emissions_stringent
# 6436                          3625>>cost_parcel_lockers
#
#                                                  effect  source  support  \
# 0                      216>>chain_supply_infrastructure   f-476        1
# 1                           1246>>winter_severely_finns  f-4849        2
# 2                      2090>>boost_profitability_profit    f-29        1
# 3                          710>>safety_improves_service   f-123        1
# 4                                 2779>>rail_speed_high  f-5198        1
# ...                                                 ...     ...      ...
# 6432                                123>>ource_arcus_ce  f-1804        1
# 6433                          2489>>harm_worker_violate   f-808        1
# 6434                        1467>>sharply_slowed_second  f-4742        1
# 6435  3273>>” don ’ t expect to see it on ustralian ...  f-4473        1
# 6436                                        769>>… no .  f-4236        1
#
#                                                evidence
# 0     to get similar to the low cost available in Ch...
# 1     a possible power shortage in the coming winter...
# 2     you do things the India way --> " Being profit...
# 3     cost of vehicles does not go up steeply . --> ...
# 4     once booked , a swipe of your ID card or passp...
# ...                                                 ...
# 6432  Measures will also need to be taken to stimula...
# 6433  We have people in Russia and we love them also...
# 6434  “ This will lock China substantially out of th...
# 6435  VW prioritises markets with stricter emissions...
# 6436  Well , it seems highly unlikely that GM Specia...
#
# [6437 rows x 5 columns]

# %%
node_df = pd.concat([
    graph_df[['cause','source']].rename(columns={'cause':'node','source':'sources'}),
    graph_df[['effect','source']].rename(columns={'effect':'node','source':'sources'})
],axis=0).drop_duplicates().reset_index(drop=True)
node_df
# Out:
#                                                     node sources
# 0                            693>>cheap_mass_inexpensive   f-476
# 1                            1246>>winter_severely_finns  f-4849
# 2                                  3114>>sort_things_you    f-29
# 3                           832>>steeply_waits_expensive   f-123
# 4      766>>once booked , a swipe of your ID card or ...  f-5198
# ...                                                  ...     ...
# 12272                                123>>ource_arcus_ce  f-1804
# 12273                          2489>>harm_worker_violate   f-808
# 12274                        1467>>sharply_slowed_second  f-4742
# 12275  3273>>” don ’ t expect to see it on ustralian ...  f-4473
# 12276                                        769>>… no .  f-4236
#
# [12277 rows x 2 columns]

# %%
graph_df.to_csv(os.path.join(graph_folder,'graph.csv'), index=False, encoding='utf-8-sig')
node_df.to_csv(os.path.join(graph_folder,'node_df.csv'), index=False, encoding='utf-8-sig')
